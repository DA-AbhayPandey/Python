# %%
# Application Programming Interface 
# it act like middle man - between two application
# it let you pull data from server (only those data which server allowed) 
# and provide you the data (not let you access data which server  restricted )

# %%
#Copied python data from coinmarketcap 

#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com./v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '7aeef531-9ab2-4b90-84f3-6542597dae10',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-05-17T11:54:20.792Z', 'error_code': 0, 'error_message': None, 'elapsed': 1225, 'credit_count': 1, 'notice': None, 'total_count': 9965}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11047, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19699509, 'total_supply': 19699509, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-05-17T11:52:00.000Z', 'quote': {'USD': {'price': 66297.74736799242, 'volume_24h': 31417051732.695263, 'volume_change_24h': -23.7307, 'percent_change_1h': -0.20990323, 'percent_change_24h': 0.06243499, 'percent_change_7d': 4.92503804, 'percent_change_30d': 5.29059587, 'percent_change_60d': -2.80751881, 'percent_change_90d': 28.11024775, 'market_cap': 1306033070955.493, 'market_cap_dominance': 54.3625, 'fully_diluted_market_cap': 1392252694727.84, 'tvl': None, 'last_updated': '2024-05-17T11:52:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 8938, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120120311.4109436, 'total_supply': 120120311.4109436, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-05-17T11:51:00.000Z', 'quote': {'USD': {'price': 3034.175286024888, 'volume_24h': 14447923480.423162, 'volume_change_24h': -5.5482, 'percent_change_1h': -0.10485893, 'percent_change_24h': 0.99470866, 'percent_change_7d': 0.12761253, 'percent_change_30d': -0.61709544, 'percent_change_60d': -15.69749898, 'percent_change_90d': 9.00558243, 'market_cap': 364466080232.6984, 'market_cap_dominance': 15.176, 'fully_diluted_market_cap': 364466080232.7, 'tvl': None, 'last_updated': '2024-05-17T11:51:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 85792, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 111205483123.85364, 'total_supply': 114086550454.4213 ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

#This allows you to see all the columns& rowa, not just like 15

pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe
df=pd.json_normalize(data['data'])
df['TimeStampe']=pd.to_datetime('now')
df

#I changed 'limit':'5000' to 15 in parameters command in first cell
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11047
# 1    1027     Ethereum    ETH      ethereum              8938
# 2     825  Tether USDt   USDT        tether             85792
# 3    1839          BNB    BNB           bnb              2162
# 4    5426       Solana    SOL        solana               660
# 5    3408         USDC   USDC      usd-coin             19180
# 6      52          XRP    XRP           xrp              1316
# 7   11419      Toncoin    TON       toncoin               329
# 8      74     Dogecoin   DOGE      dogecoin               965
# 9    2010      Cardano    ADA       cardano              1171
# 10   5994    Shiba Inu   SHIB     shiba-inu               807
# 11   5805    Avalanche   AVAX     avalanche               721
# 12   1958         TRON    TRX          tron               973
# 13   6636     Polkadot    DOT  polkadot-new               759
# 14   1975    Chainlink   LINK     chainlink              1753
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2021-08-26T13:40:22.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2020-08-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2017-09-13T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.969951e+07  1.969951e+07            False       NaN         1
# 1         1.201203e+08  1.201203e+08             True       NaN         2
# 2         1.112055e+11  1.140866e+11             True       NaN         3
# 3         1.475865e+08  1.475865e+08            False       NaN         4
# 4         4.488047e+08  5.761681e+08             True       NaN         5
# 5         3.331868e+10  3.331868e+10            False       NaN         6
# 6         5.528895e+10  9.998761e+10            False       NaN         7
# 7         3.474217e+09  5.106701e+09             True       NaN         8
# 8         1.443267e+11  1.443267e+11             True       NaN         9
# 9         3.567269e+10  3.688363e+10            False       NaN        10
# 10        5.892719e+14  5.895200e+14            False       NaN        11
# 11        3.823351e+08  4.410247e+08            False       NaN        12
# 12        8.745212e+10  8.745221e+10             True       NaN        13
# 13        1.437953e+09  1.437953e+09             True       NaN        14
# 14        5.871000e+08  1.000000e+09            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                       3.414167e+09              2.272454e+10      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                      7.165966e+10              8.945308e+09      None
# 13                      1.445944e+09              1.043863e+10      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-05-17T11:52:00.000Z     66297.747368          3.141705e+10
# 1   2024-05-17T11:51:00.000Z      3034.175286          1.444792e+10
# 2   2024-05-17T11:51:00.000Z         1.000080          6.126538e+10
# 3   2024-05-17T11:51:00.000Z       579.243621          1.775596e+09
# 4   2024-05-17T11:51:00.000Z       168.142877          3.617173e+09
# 5   2024-05-17T11:51:00.000Z         0.999959          6.809841e+09
# 6   2024-05-17T11:52:00.000Z         0.520870          1.129017e+09
# 7   2024-05-17T11:51:00.000Z         6.655956          6.454955e+08
# 8   2024-05-17T11:52:00.000Z         0.152424          1.159736e+09
# 9   2024-05-17T11:51:00.000Z         0.487996          4.616053e+08
# 10  2024-05-17T11:51:00.000Z         0.000025          6.352928e+08
# 11  2024-05-17T11:51:00.000Z        36.706403          5.082669e+08
# 12  2024-05-17T11:51:00.000Z         0.124830          3.454678e+08
# 13  2024-05-17T11:51:00.000Z         7.219250          2.353454e+08
# 14  2024-05-17T11:51:00.000Z        16.591225          1.240607e+09
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -23.7307                    -0.209903
# 1                       -5.5482                    -0.104859
# 2                      -18.3527                     0.004480
# 3                      -13.1372                     0.199611
# 4                      -17.3501                    -0.187623
# 5                      -19.9562                    -0.000063
# 6                       -8.3968                    -0.197305
# 7                       10.6252                    -0.415149
# 8                      -37.3975                    -0.380818
# 9                        9.8848                     0.437059
# 10                     -44.8540                    -0.181868
# 11                       4.9824                    -0.332791
# 12                      10.0221                     0.470618
# 13                       0.2543                    -0.405929
# 14                     250.7238                     1.180270
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.062435                     4.925038
# 1                       0.994709                     0.127613
# 2                      -0.041634                     0.017391
# 3                      -0.451872                    -2.711479
# 4                       3.047544                     9.248132
# 5                      -0.018221                    -0.003821
# 6                       0.437756                     1.089162
# 7                       0.695675                    -4.443373
# 8                      -1.495873                     1.076973
# 9                       7.238039                     5.132733
# 10                     -1.431390                     6.107803
# 11                      6.156172                     2.991281
# 12                      0.060027                    -0.083122
# 13                      4.554236                     1.594166
# 14                     19.772511                    16.077560
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       5.290596                     -2.807519
# 1                      -0.617095                    -15.697499
# 2                      -0.052580                      0.118718
# 3                       8.235913                      1.748516
# 4                      23.808882                    -18.673445
# 5                      -0.009865                      0.002367
# 6                       6.332723                    -14.890169
# 7                       7.924532                     72.779099
# 8                      -0.998841                      3.221864
# 9                       8.375878                    -28.697950
# 10                     13.183561                    -11.877885
# 11                      7.672641                    -42.552249
# 12                     11.067045                     -0.761619
# 13                      9.857256                    -29.706003
# 14                     24.984026                    -14.011399
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      28.110248          1.306033e+12
# 1                       9.005582          3.644661e+11
# 2                      -0.022750          1.112144e+11
# 3                      62.126423          8.548852e+10
# 4                      53.539744          7.546331e+10
# 5                      -0.000927          3.331732e+10
# 6                      -6.055440          2.879836e+10
# 7                     204.999991          2.312423e+10
# 8                      80.054379          2.199890e+10
# 9                     -16.870386          1.740813e+10
# 10                    156.221800          1.462932e+10
# 11                     -7.541348          1.403415e+10
# 12                     -9.141820          1.091669e+10
# 13                     -4.974905          1.038095e+10
# 14                    -15.174219          9.740708e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          54.3625                        1.392253e+12
# 1                          15.1760                        3.644661e+11
# 2                           4.6308                        1.140957e+11
# 3                           3.5596                        8.548852e+10
# 4                           3.1422                        9.687856e+10
# 5                           1.3873                        3.331732e+10
# 6                           1.1987                        5.208701e+10
# 7                           0.9629                        3.398997e+10
# 8                           0.9157                        2.199890e+10
# 9                           0.7249                        2.195982e+10
# 10                          0.6091                        1.463548e+10
# 11                          0.5844                        2.627256e+10
# 12                          0.4546                        1.091670e+10
# 13                          0.4323                        1.038095e+10
# 14                          0.4056                        1.659123e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-05-17T11:52:00.000Z          NaN           NaN
# 1           None  2024-05-17T11:51:00.000Z          NaN           NaN
# 2           None  2024-05-17T11:51:00.000Z       1027.0      Ethereum
# 3           None  2024-05-17T11:51:00.000Z          NaN           NaN
# 4           None  2024-05-17T11:51:00.000Z          NaN           NaN
# 5           None  2024-05-17T11:51:00.000Z       1027.0      Ethereum
# 6           None  2024-05-17T11:52:00.000Z          NaN           NaN
# 7           None  2024-05-17T11:51:00.000Z          NaN           NaN
# 8           None  2024-05-17T11:52:00.000Z          NaN           NaN
# 9           None  2024-05-17T11:51:00.000Z          NaN           NaN
# 10          None  2024-05-17T11:51:00.000Z       1027.0      Ethereum
# 11          None  2024-05-17T11:51:00.000Z          NaN           NaN
# 12          None  2024-05-17T11:51:00.000Z          NaN           NaN
# 13          None  2024-05-17T11:51:00.000Z          NaN           NaN
# 14          None  2024-05-17T11:51:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                    TimeStampe
# 0  2024-05-17 17:24:43.854522
# 1  2024-05-17 17:24:43.854522
# 2  2024-05-17 17:24:43.854522
# 3  2024-05-17 17:24:43.854522
# 4  2024-05-17 17:24:43.854522
# 5  2024-05-17 17:24:43.854522
# 6  2024-05-17 17:24:43.854522
# 7  2024-05-17 17:24:43.854522
# 8  2024-05-17 17:24:43.854522
# 9  2024-05-17 17:24:43.854522
# 10 2024-05-17 17:24:43.854522
# 11 2024-05-17 17:24:43.854522
# 12 2024-05-17 17:24:43.854522
# 13 2024-05-17 17:24:43.854522
# 14 2024-05-17 17:24:43.854522

# %%
def api_runner():
    global df

    url = 'https://pro-api.coinmarketcap.com./v1/cryptocurrency/listings/latest'
    parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
    }
    headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': '7aeef531-9ab2-4b90-84f3-6542597dae10',
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)
        
    df2=pd.json_normalize(data['data'])
    df2['TimeStampe']=pd.to_datetime('now')
    df=df._append(df2)
    
     # Use this if you want to create a csv and append data to it
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df
    #if not os.path.isfile(r"C:\Users\ASUS\Downloads\Data Analyst\Python\Python File sorter\API_Test"):
         #df.to_csv(r"C:\Users\ASUS\Downloads\Data Analyst\Python\Python File sorter\API_Test.csv", header='column_names')
    #else:
        #df.to_csv(r"C:\Users\ASUS\Downloads\Data Analyst\Python\Python File sorter\API_Test.csv", mode='a', header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):    #range(333) used bcoz site allowed us only 333 api runner in a day
    api_runner()
    print('Api ran Successfully')
    sleep(120)           #sleep for 2 min
exit()
# Out:
# {'status': {'timestamp': '2024-05-17T12:52:52.804Z', 'error_code': 0, 'error_message': None, 'elapsed': 21, 'credit_count': 1, 'notice': None, 'total_count': 9965}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11047, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19699509, 'total_supply': 19699509, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-05-17T12:51:00.000Z', 'quote': {'USD': {'price': 66445.76938353461, 'volume_24h': 30129285488.80777, 'volume_change_24h': -23.7659, 'percent_change_1h': 0.16279244, 'percent_change_24h': 0.22174329, 'percent_change_7d': 5.51764343, 'percent_change_30d': 6.49780852, 'percent_change_60d': -2.82214998, 'percent_change_90d': 28.45634089, 'market_cap': 1308949031982.8645, 'market_cap_dominance': 54.4258, 'fully_diluted_market_cap': 1395361157054.23, 'tvl': None, 'last_updated': '2024-05-17T12:51:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 8938, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120120311.4109436, 'total_supply': 120120311.4109436, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-05-17T12:50:00.000Z', 'quote': {'USD': {'price': 3074.324437368553, 'volume_24h': 14170769433.839817, 'volume_change_24h': -4.59, 'percent_change_1h': 1.30673454, 'percent_change_24h': 2.72854272, 'percent_change_7d': 1.65009299, 'percent_change_30d': 1.58043798, 'percent_change_60d': -14.28533235, 'percent_change_90d': 10.34166065, 'market_cap': 369288808794.98456, 'market_cap_dominance': 15.3549, 'fully_diluted_market_cap': 369288808794.98, 'tvl': None, 'last_updated': '2024-05-17T12:50:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 85794, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 111205483123.85364, 'total_supply': 114086550454.42137,  ...
# Api ran Successfully
# {'status': {'timestamp': '2024-05-17T12:54:53.879Z', 'error_code': 0, 'error_message': None, 'elapsed': 26, 'credit_count': 1, 'notice': None, 'total_count': 9965}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11047, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19699509, 'total_supply': 19699509, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-05-17T12:53:00.000Z', 'quote': {'USD': {'price': 66505.19554271617, 'volume_24h': 30151079311.715473, 'volume_change_24h': -23.6388, 'percent_change_1h': 0.28934127, 'percent_change_24h': 0.35600909, 'percent_change_7d': 5.52679767, 'percent_change_30d': 6.57673054, 'percent_change_60d': -2.86275026, 'percent_change_90d': 28.59770704, 'market_cap': 1310119698140.497, 'market_cap_dominance': 54.3523, 'fully_diluted_market_cap': 1396609106397.04, 'tvl': None, 'last_updated': '2024-05-17T12:53:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 8938, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120120311.4109436, 'total_supply': 120120311.4109436, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-05-17T12:52:00.000Z', 'quote': {'USD': {'price': 3075.152235132247, 'volume_24h': 14200818716.986622, 'volume_change_24h': -4.3255, 'percent_change_1h': 1.39861619, 'percent_change_24h': 2.7844408, 'percent_change_7d': 1.61644405, 'percent_change_30d': 1.45547916, 'percent_change_60d': -14.3514668, 'percent_change_90d': 10.35598988, 'market_cap': 369388244120.1448, 'market_cap_dominance': 15.3246, 'fully_diluted_market_cap': 369388244120.14, 'tvl': None, 'last_updated': '2024-05-17T12:52:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 85794, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 111205483123.85364, 'total_supply': 114086550454.42137, ' ...
# Api ran Successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 8
#       6     api_runner()
#       7     print('Api ran Successfully')
# ----> 8     sleep(120)           #sleep for 2 min
#       9 exit()
#
# KeyboardInterrupt:

# %%
#df.read_csv(r"C:\Users\ASUS\Downloads\Data Analyst\Python\Python File sorter\API_Test.csv")

# %%
df
# we complete API project successfully, 
#Now we just do some clean up and Visualization
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11047
# 1    1027     Ethereum    ETH      ethereum              8938
# 2     825  Tether USDt   USDT        tether             85794
# 3    1839          BNB    BNB           bnb              2162
# 4    5426       Solana    SOL        solana               660
# 5    3408         USDC   USDC      usd-coin             19181
# 6      52          XRP    XRP           xrp              1316
# 7   11419      Toncoin    TON       toncoin               329
# 8      74     Dogecoin   DOGE      dogecoin               965
# 9    2010      Cardano    ADA       cardano              1171
# 10   5994    Shiba Inu   SHIB     shiba-inu               807
# 11   5805    Avalanche   AVAX     avalanche               721
# 12   1958         TRON    TRX          tron               973
# 13   6636     Polkadot    DOT  polkadot-new               759
# 14   1975    Chainlink   LINK     chainlink              1753
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2021-08-26T13:40:22.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2020-08-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2017-09-13T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.969951e+07  1.969951e+07            False       NaN         1
# 1         1.201203e+08  1.201203e+08             True       NaN         2
# 2         1.112055e+11  1.140866e+11             True       NaN         3
# 3         1.475865e+08  1.475865e+08            False       NaN         4
# 4         4.488047e+08  5.761681e+08             True       NaN         5
# 5         3.331868e+10  3.331868e+10            False       NaN         6
# 6         5.528895e+10  9.998761e+10            False       NaN         7
# 7         3.474217e+09  5.106701e+09             True       NaN         8
# 8         1.443267e+11  1.443267e+11             True       NaN         9
# 9         3.567269e+10  3.688363e+10            False       NaN        10
# 10        5.892719e+14  5.895200e+14            False       NaN        11
# 11        3.823351e+08  4.410247e+08            False       NaN        12
# 12        8.745212e+10  8.745221e+10             True       NaN        13
# 13        1.437953e+09  1.437953e+09             True       NaN        14
# 14        5.871000e+08  1.000000e+09            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                       3.414167e+09              2.289299e+10      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                      7.165966e+10              8.939663e+09      None
# 13                      1.445944e+09              1.048732e+10      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-05-17T12:53:00.000Z     66505.195543          3.015108e+10
# 1   2024-05-17T12:52:00.000Z      3075.152235          1.420082e+10
# 2   2024-05-17T12:52:00.000Z         1.000023          5.908717e+10
# 3   2024-05-17T12:52:00.000Z       579.717505          1.690257e+09
# 4   2024-05-17T12:52:00.000Z       168.530084          3.566526e+09
# 5   2024-05-17T12:52:00.000Z         1.000024          6.604979e+09
# 6   2024-05-17T12:53:00.000Z         0.523923          1.105567e+09
# 7   2024-05-17T12:52:00.000Z         6.705293          5.908258e+08
# 8   2024-05-17T12:53:00.000Z         0.153526          1.114817e+09
# 9   2024-05-17T12:52:00.000Z         0.486622          4.585059e+08
# 10  2024-05-17T12:52:00.000Z         0.000025          5.941733e+08
# 11  2024-05-17T12:52:00.000Z        36.913524          4.943746e+08
# 12  2024-05-17T12:52:00.000Z         0.124752          3.290630e+08
# 13  2024-05-17T12:53:00.000Z         7.252925          2.316903e+08
# 14  2024-05-17T12:52:00.000Z        16.621252          1.269996e+09
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -23.6388                     0.289341
# 1                       -4.3255                     1.398616
# 2                      -18.7589                    -0.039008
# 3                      -17.9670                     0.131973
# 4                      -14.2913                     0.323951
# 5                      -19.4287                    -0.009663
# 6                       -7.9059                     0.584349
# 7                       -5.3843                     0.754845
# 8                      -35.8733                     0.721941
# 9                       12.9551                    -0.282385
# 10                     -46.6159                     0.868578
# 11                       7.8669                     0.635771
# 12                       0.9445                    -0.068114
# 13                       5.0280                     0.483571
# 14                     273.5812                     0.293214
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.356009                     5.526798
# 1                       2.784441                     1.616444
# 2                      -0.061573                     0.000150
# 3                       0.159130                    -2.459845
# 4                       3.722812                     9.846849
# 5                      -0.034043                     0.003076
# 6                       1.399088                     2.227645
# 7                       2.763948                    -5.327851
# 8                      -0.183598                     2.182529
# 9                       7.212804                     5.005182
# 10                     -0.033860                     7.074940
# 11                      7.221442                     3.545338
# 12                     -0.351965                     0.096300
# 13                      5.600324                     2.584366
# 14                     20.300337                    16.738184
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       6.576731                     -2.862750
# 1                       1.455479                    -14.351467
# 2                      -0.041146                      0.111952
# 3                       8.075476                      2.414898
# 4                      27.625505                    -18.866803
# 5                       0.003138                      0.014531
# 6                       7.751435                    -14.122921
# 7                       9.176822                     74.417416
# 8                       1.009378                      3.630670
# 9                       9.613767                    -28.433763
# 10                     14.651648                    -11.204369
# 11                     10.056916                    -42.078054
# 12                     11.538561                     -0.435500
# 13                     11.427739                    -28.243342
# 14                     26.259493                    -13.411731
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      28.597707          1.310120e+12
# 1                      10.355990          3.693882e+11
# 2                      -0.023443          1.112081e+11
# 3                      61.753546          8.555846e+10
# 4                      54.021894          7.563709e+10
# 5                       0.008525          3.331947e+10
# 6                      -5.521373          2.896713e+10
# 7                     205.943727          2.329564e+10
# 8                      81.329798          2.215795e+10
# 9                     -17.279838          1.735913e+10
# 10                    158.049273          1.474614e+10
# 11                     -7.313042          1.411334e+10
# 12                    -10.258067          1.090980e+10
# 13                     -4.871229          1.042937e+10
# 14                    -16.084313          9.758337e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          54.3523                        1.396609e+12
# 1                          15.3246                        3.693882e+11
# 2                           4.6136                        1.140892e+11
# 3                           3.5495                        8.555846e+10
# 4                           3.1379                        9.710165e+10
# 5                           1.3823                        3.331947e+10
# 6                           1.2017                        5.239227e+10
# 7                           0.9665                        3.424193e+10
# 8                           0.9193                        2.215795e+10
# 9                           0.7202                        2.189801e+10
# 10                          0.6118                        1.475234e+10
# 11                          0.5855                        2.642081e+10
# 12                          0.4526                        1.090981e+10
# 13                          0.4327                        1.042937e+10
# 14                          0.4048                        1.662125e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-05-17T12:53:00.000Z          NaN           NaN
# 1           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 2           None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
# 3           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 4           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 5           None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
# 6           None  2024-05-17T12:53:00.000Z          NaN           NaN
# 7           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 8           None  2024-05-17T12:53:00.000Z          NaN           NaN
# 9           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 10          None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
# 11          None  2024-05-17T12:52:00.000Z          NaN           NaN
# 12          None  2024-05-17T12:52:00.000Z          NaN           NaN
# 13          None  2024-05-17T12:53:00.000Z          NaN           NaN
# 14          None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2024-05-17 18:24:53.942468
# 1  2024-05-17 18:24:53.942468
# 2  2024-05-17 18:24:53.942468
# 3  2024-05-17 18:24:53.942468
# 4  2024-05-17 18:24:53.942468
# 5  2024-05-17 18:24:53.942468
# 6  2024-05-17 18:24:53.942468
# 7  2024-05-17 18:24:53.942468
# 8  2024-05-17 18:24:53.942468
# 9  2024-05-17 18:24:53.942468
# 10 2024-05-17 18:24:53.942468
# 11 2024-05-17 18:24:53.942468
# 12 2024-05-17 18:24:53.942468
# 13 2024-05-17 18:24:53.942468
# 14 2024-05-17 18:24:53.942468

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x) # we customize the float type into(1 digit after decimal) format

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11047
# 1    1027     Ethereum    ETH      ethereum              8938
# 2     825  Tether USDt   USDT        tether             85794
# 3    1839          BNB    BNB           bnb              2162
# 4    5426       Solana    SOL        solana               660
# 5    3408         USDC   USDC      usd-coin             19181
# 6      52          XRP    XRP           xrp              1316
# 7   11419      Toncoin    TON       toncoin               329
# 8      74     Dogecoin   DOGE      dogecoin               965
# 9    2010      Cardano    ADA       cardano              1171
# 10   5994    Shiba Inu   SHIB     shiba-inu               807
# 11   5805    Avalanche   AVAX     avalanche               721
# 12   1958         TRON    TRX          tron               973
# 13   6636     Polkadot    DOT  polkadot-new               759
# 14   1975    Chainlink   LINK     chainlink              1753
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2021-08-26T13:40:22.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2020-08-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2017-09-13T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags     max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.0
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...            NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...            NaN
# 3   [marketplace, centralized-exchange, payments, ...            NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...            NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...            NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.0
# 7   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...            NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...            NaN
# 9   [dpos, pos, platform, research, smart-contract...  45000000000.0
# 10      [memes, ethereum-ecosystem, doggone-doggerel]            NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...    715748719.0
# 12  [media, payments, tron-ecosystem, layer-1, dwf...            NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...            NaN
# 14  [platform, defi, oracles, smart-contracts, sub...   1000000000.0
#
#     circulating_supply      total_supply  infinite_supply  platform  cmc_rank  \
# 0           19699509.0        19699509.0            False       NaN         1
# 1          120120311.4       120120311.4             True       NaN         2
# 2       111205483123.9    114086550454.4             True       NaN         3
# 3          147586472.6       147586472.6            False       NaN         4
# 4          448804697.2       576168076.2             True       NaN         5
# 5        33318682954.5     33318682954.5            False       NaN         6
# 6        55288951055.0     99987612649.0            False       NaN         7
# 7         3474216990.3      5106700920.2             True       NaN         8
# 8       144326656383.7    144326656383.7             True       NaN         9
# 9        35672692022.6     36883631806.2            False       NaN        10
# 10   589271906918956.6 589520023734666.4            False       NaN        11
# 11         382335088.9       441024728.9            False       NaN        12
# 12       87452116916.2     87452206443.3             True       NaN        13
# 13        1437953431.4      1437953431.4             True       NaN        14
# 14         587099970.5      1000000000.0            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                       3414166606.0             22892988898.5      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                     71659659264.0              8939663433.5      None
# 13                      1445943894.0             10487322857.0      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-05-17T12:53:00.000Z          66505.2         30151079311.7
# 1   2024-05-17T12:52:00.000Z           3075.2         14200818717.0
# 2   2024-05-17T12:52:00.000Z              1.0         59087173789.7
# 3   2024-05-17T12:52:00.000Z            579.7          1690257047.6
# 4   2024-05-17T12:52:00.000Z            168.5          3566526452.5
# 5   2024-05-17T12:52:00.000Z              1.0          6604978630.9
# 6   2024-05-17T12:53:00.000Z              0.5          1105566737.7
# 7   2024-05-17T12:52:00.000Z              6.7           590825828.3
# 8   2024-05-17T12:53:00.000Z              0.2          1114816935.0
# 9   2024-05-17T12:52:00.000Z              0.5           458505885.3
# 10  2024-05-17T12:52:00.000Z              0.0           594173288.5
# 11  2024-05-17T12:52:00.000Z             36.9           494374609.8
# 12  2024-05-17T12:52:00.000Z              0.1           329062986.7
# 13  2024-05-17T12:53:00.000Z              7.3           231690258.6
# 14  2024-05-17T12:52:00.000Z             16.6          1269995614.4
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                         -23.6                          0.3
# 1                          -4.3                          1.4
# 2                         -18.8                         -0.0
# 3                         -18.0                          0.1
# 4                         -14.3                          0.3
# 5                         -19.4                         -0.0
# 6                          -7.9                          0.6
# 7                          -5.4                          0.8
# 8                         -35.9                          0.7
# 9                          13.0                         -0.3
# 10                        -46.6                          0.9
# 11                          7.9                          0.6
# 12                          0.9                         -0.1
# 13                          5.0                          0.5
# 14                        273.6                          0.3
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                            0.4                          5.5
# 1                            2.8                          1.6
# 2                           -0.1                          0.0
# 3                            0.2                         -2.5
# 4                            3.7                          9.8
# 5                           -0.0                          0.0
# 6                            1.4                          2.2
# 7                            2.8                         -5.3
# 8                           -0.2                          2.2
# 9                            7.2                          5.0
# 10                          -0.0                          7.1
# 11                           7.2                          3.5
# 12                          -0.4                          0.1
# 13                           5.6                          2.6
# 14                          20.3                         16.7
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                            6.6                          -2.9
# 1                            1.5                         -14.4
# 2                           -0.0                           0.1
# 3                            8.1                           2.4
# 4                           27.6                         -18.9
# 5                            0.0                           0.0
# 6                            7.8                         -14.1
# 7                            9.2                          74.4
# 8                            1.0                           3.6
# 9                            9.6                         -28.4
# 10                          14.7                         -11.2
# 11                          10.1                         -42.1
# 12                          11.5                          -0.4
# 13                          11.4                         -28.2
# 14                          26.3                         -13.4
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                           28.6       1310119698140.5
# 1                           10.4        369388244120.1
# 2                           -0.0        111208094935.9
# 3                           61.8         85558461711.5
# 4                           54.0         75637093422.5
# 5                            0.0         33319473695.4
# 6                           -5.5         28967133922.9
# 7                          205.9         23295644345.6
# 8                           81.3         22157954203.5
# 9                          -17.3         17359133087.7
# 10                         158.0         14746135561.9
# 11                          -7.3         14113335614.7
# 12                         -10.3         10909799178.6
# 13                          -4.9         10429368629.8
# 14                         -16.1          9758336596.1
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                             54.4                     1396609106397.0
# 1                             15.3                      369388244120.1
# 2                              4.6                      114089229932.3
# 3                              3.5                       85558461711.5
# 4                              3.1                       97101654407.2
# 5                              1.4                       33319473695.5
# 6                              1.2                       52392265308.3
# 7                              1.0                       34241928108.8
# 8                              0.9                       22157954203.5
# 9                              0.7                       21898010625.4
# 10                             0.6                       14752344519.3
# 11                             0.6                       26420807770.0
# 12                             0.5                       10909810347.2
# 13                             0.4                       10429368629.8
# 14                             0.4                       16621252064.8
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-05-17T12:53:00.000Z          NaN           NaN
# 1           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 2           None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
# 3           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 4           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 5           None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
# 6           None  2024-05-17T12:53:00.000Z          NaN           NaN
# 7           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 8           None  2024-05-17T12:53:00.000Z          NaN           NaN
# 9           None  2024-05-17T12:52:00.000Z          NaN           NaN
# 10          None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
# 11          None  2024-05-17T12:52:00.000Z          NaN           NaN
# 12          None  2024-05-17T12:52:00.000Z          NaN           NaN
# 13          None  2024-05-17T12:53:00.000Z          NaN           NaN
# 14          None  2024-05-17T12:52:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2024-05-17 18:24:53.942468
# 1  2024-05-17 18:24:53.942468
# 2  2024-05-17 18:24:53.942468
# 3  2024-05-17 18:24:53.942468
# 4  2024-05-17 18:24:53.942468
# 5  2024-05-17 18:24:53.942468
# 6  2024-05-17 18:24:53.942468
# 7  2024-05-17 18:24:53.942468
# 8  2024-05-17 18:24:53.942468
# 9  2024-05-17 18:24:53.942468
# 10 2024-05-17 18:24:53.942468
# 11 2024-05-17 18:24:53.942468
# 12 2024-05-17 18:24:53.942468
# 13 2024-05-17 18:24:53.942468
# 14 2024-05-17 18:24:53.942468

# %%
df2=df.set_index('name')
df3=df2.filter(items=['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],axis=1)
df3
#df2=df.set_index('Country')
#df2.filter(items=['Continent','CCA3'], axis=1)
# Out:
#              quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# name
# Bitcoin                               0.4                          5.5
# Ethereum                              2.8                          1.6
# Tether USDt                          -0.1                          0.0
# BNB                                   0.2                         -2.5
# Solana                                3.7                          9.8
# USDC                                 -0.0                          0.0
# XRP                                   1.4                          2.2
# Toncoin                               2.8                         -5.3
# Dogecoin                             -0.2                          2.2
# Cardano                               7.2                          5.0
# Shiba Inu                            -0.0                          7.1
# Avalanche                             7.2                          3.5
# TRON                                 -0.4                          0.1
# Polkadot                              5.6                          2.6
# Chainlink                            20.3                         16.7
#
#              quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# name
# Bitcoin                               6.6                          -2.9
# Ethereum                              1.5                         -14.4
# Tether USDt                          -0.0                           0.1
# BNB                                   8.1                           2.4
# Solana                               27.6                         -18.9
# USDC                                  0.0                           0.0
# XRP                                   7.8                         -14.1
# Toncoin                               9.2                          74.4
# Dogecoin                              1.0                           3.6
# Cardano                               9.6                         -28.4
# Shiba Inu                            14.7                         -11.2
# Avalanche                            10.1                         -42.1
# TRON                                 11.5                          -0.4
# Polkadot                             11.4                         -28.2
# Chainlink                            26.3                         -13.4
#
#              quote.USD.percent_change_90d
# name
# Bitcoin                              28.6
# Ethereum                             10.4
# Tether USDt                          -0.0
# BNB                                  61.8
# Solana                               54.0
# USDC                                  0.0
# XRP                                  -5.5
# Toncoin                             205.9
# Dogecoin                             81.3
# Cardano                             -17.3
# Shiba Inu                           158.0
# Avalanche                            -7.3
# TRON                                -10.3
# Polkadot                             -4.9
# Chainlink                           -16.1

# %%
df4=df3.stack()
df4
# Out:
# name
# Bitcoin    quote.USD.percent_change_24h     0.4
#            quote.USD.percent_change_7d      5.5
#            quote.USD.percent_change_30d     6.6
#            quote.USD.percent_change_60d    -2.9
#            quote.USD.percent_change_90d    28.6
#                                            ...
# Chainlink  quote.USD.percent_change_24h    20.3
#            quote.USD.percent_change_7d     16.7
#            quote.USD.percent_change_30d    26.3
#            quote.USD.percent_change_60d   -13.4
#            quote.USD.percent_change_90d   -16.1
# Length: 75, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5=df4.to_frame(name='values')
df5
# Out:
#                                         values
# name
# Bitcoin   quote.USD.percent_change_24h     0.4
#           quote.USD.percent_change_7d      5.5
#           quote.USD.percent_change_30d     6.6
#           quote.USD.percent_change_60d    -2.9
#           quote.USD.percent_change_90d    28.6
# ...                                        ...
# Chainlink quote.USD.percent_change_24h    20.3
#           quote.USD.percent_change_7d     16.7
#           quote.USD.percent_change_30d    26.3
#           quote.USD.percent_change_60d   -13.4
#           quote.USD.percent_change_90d   -16.1
#
# [75 rows x 1 columns]

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    75
# dtype: int64

# %%
index=pd.Index(range(90))

df6= df5.reset_index()
df6
# Out:
#          name                       level_1  values
# 0     Bitcoin  quote.USD.percent_change_24h     0.4
# 1     Bitcoin   quote.USD.percent_change_7d     5.5
# 2     Bitcoin  quote.USD.percent_change_30d     6.6
# 3     Bitcoin  quote.USD.percent_change_60d    -2.9
# 4     Bitcoin  quote.USD.percent_change_90d    28.6
# ..        ...                           ...     ...
# 70  Chainlink  quote.USD.percent_change_24h    20.3
# 71  Chainlink   quote.USD.percent_change_7d    16.7
# 72  Chainlink  quote.USD.percent_change_30d    26.3
# 73  Chainlink  quote.USD.percent_change_60d   -13.4
# 74  Chainlink  quote.USD.percent_change_90d   -16.1
#
# [75 rows x 3 columns]

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#ax = plt.subplots(figsize=(10,5))
sb.catplot(x='level_1', y='values', hue='name', data=df6, kind='point', height=6, aspect=3)

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want
df7=df[['name','quote.USD.price','timestamp']]
df7=df7.query("name=='Bitcoin'")
df7
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin          66505.2 2024-05-17 18:24:53.942468

# %%
#sns.set_theme(style="darkgrid")                  --- for darkmode


#sb.lineplot(x='timestamp', y= 'quote.USD.price', data=df7)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
