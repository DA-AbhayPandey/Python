# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\Data Analyst\Python\Python File sorter\Ice Cream Ratings.csv",index_col=('Date'))
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
#matplotlib.pyplot can be use to change visualization/style of chart
print(mp.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
mp.style.use('fivethirtyeight') #check below chart, it changes style compare to other charts below

# %%
#df.plot()    # .plot display line chart by default
df.plot(kind='line', title='Rate Chart', ylabel = 'Rating', figsize=(8,4)) #use xlabel= for name x asis
# Out:
# <Axes: title={'center': 'Rate Chart'}, xlabel='Date', ylabel='Rating'>

# %%
df.plot(kind ='line', subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind='bar', stacked=True) #Stacked= can be use with bar chart
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind='bar', stacked=True) # we can also customise chart by giving item name right after df
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='barh') #barh used for horizontal bar grap
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.bar()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.scatter(x='Texture Rating', y='Overall Rating', s=200, c='Red') #scatter() not work untill we describe x & y axis
                                                                        #we can use s= for size , c= for color
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist() #hist() used for histogram 
               # we can use hist(bins=10) any no to adjust histagram bars
               #bins(x) no.refers no. of bars on x axis
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area(figsize=(8,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y='Flavor Rating', figsize=(7,7)) #df.plot.pie() do not work, we need to describe y=
# Out:
# <Axes: ylabel='Flavor Rating'>
